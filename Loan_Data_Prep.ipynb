# %% [markdown]
# ## Loan Data Prep

# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import date
from ipykernel import kernelapp as app

# %% [markdown]
# ## Read in Loan Data

# %%
# Read in 2017 csv files for review
df=pd.read_csv("static/data/LoanStats_2017Q1.csv", encoding="ISO-8859-1", skiprows=1, skipfooter=2)
df2=pd.read_csv("static/data/LoanStats_2017Q2.csv", encoding="ISO-8859-1",skiprows=1, skipfooter=2)
df3=pd.read_csv("static/data/LoanStats_2017Q3.csv", encoding="ISO-8859-1",skiprows=1, skipfooter=2)
df4=pd.read_csv("static/data/LoanStats_2017Q4.csv", encoding="ISO-8859-1",skiprows=1, skipfooter=2)
# Out:
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
df['purpose'].unique()
# Out:
# array(['debt_consolidation', 'home_improvement', 'car', 'major_purchase',
#        'credit_card', 'vacation', 'medical', 'other', 'house', 'moving',
#        'small_business', 'renewable_energy'], dtype=object)

# %%
# Read in 2018 csv files for review
df5=pd.read_csv("static/data/LoanStats_2018Q1.csv", encoding="ISO-8859-1", skiprows=1, skipfooter=2)
df6=pd.read_csv("static/data/LoanStats_2018Q2.csv", encoding="ISO-8859-1",skiprows=1, skipfooter=2)
df7=pd.read_csv("static/data/LoanStats_2018Q3.csv", encoding="ISO-8859-1",skiprows=1, skipfooter=2)
# Out:
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# C:\Users\15073\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
df5.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
df5['purpose'].unique()
# Out:
# array(['credit_card', 'debt_consolidation', 'house', 'home_improvement',
#        'major_purchase', 'medical', 'other', 'moving', 'car',
#        'small_business', 'vacation', 'renewable_energy', 'wedding'],
#       dtype=object)

# %% [markdown]
# ## Merge datasets

# %%
# Merge all 2017 quarters
merge = [df,df2,df3,df4]
loan_df = pd.concat(merge, sort=True)
loan_df.head()
# Out:
#    acc_now_delinq  acc_open_past_24mths addr_state  all_util  annual_inc  \
# 0               0                     8         SD      56.0    130000.0
# 1               0                     4         MI      61.0     55000.0
# 2               0                    15         CA      65.0    100000.0
# 3               0                    12         NY      57.0     95000.0
# 4               0                     1         MT      43.0     67000.0
#
#    annual_inc_joint application_type  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0               NaN       Individual       2766.0          3350.0     58.1
# 1               NaN       Individual      17223.0          7934.0     67.3
# 2               NaN       Individual      42743.0         22577.0     53.0
# 3               NaN       Individual       2156.0          9964.0     49.4
# 4               NaN       Individual      28493.0          5327.0     62.0
#
# ...

# %%
# Merge all 2018 quarters
merge2 = [df5,df6,df7]
loan2_df = pd.concat(merge, sort=True)
loan2_df.head()
# Out:
#    acc_now_delinq  acc_open_past_24mths addr_state  all_util  annual_inc  \
# 0               0                     8         SD      56.0    130000.0
# 1               0                     4         MI      61.0     55000.0
# 2               0                    15         CA      65.0    100000.0
# 3               0                    12         NY      57.0     95000.0
# 4               0                     1         MT      43.0     67000.0
#
#    annual_inc_joint application_type  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0               NaN       Individual       2766.0          3350.0     58.1
# 1               NaN       Individual      17223.0          7934.0     67.3
# 2               NaN       Individual      42743.0         22577.0     53.0
# 3               NaN       Individual       2156.0          9964.0     49.4
# 4               NaN       Individual      28493.0          5327.0     62.0
#
# ...

# %% [markdown]
# ## Retain Secured Loan Data Only

# %%
#keep just secured loan data
type_list = ('car','house','home_improvement')
secured_df = loan_df.loc[loan_df['purpose'].isin(type_list)]
secured_df.head()
# Out:
#     acc_now_delinq  acc_open_past_24mths addr_state  all_util  annual_inc  \
# 1                0                     4         MI      61.0     55000.0
# 4                0                     1         MT      43.0     67000.0
# 7                0                     2         VA      70.0    114000.0
# 25               0                     4         AZ      42.0     56000.0
# 30               0                     1         FL      51.0     65000.0
#
#     annual_inc_joint application_type  avg_cur_bal  bc_open_to_buy  bc_util  \
# 1                NaN       Individual      17223.0          7934.0     67.3
# 4                NaN       Individual      28493.0          5327.0     62.0
# 7                NaN       Individual      24630.0          1481.0     95.5
# 25               NaN       Individual      10710.0         17592.0     20.0
# 30               NaN       Individual      33958.0           722.0     27.8
#
# ...

# %%
type_list2 = ('car','house','home_improvement')
secured_df2 = loan2_df.loc[loan2_df['purpose'].isin(type_list)]
secured_df2.head()
# Out:
#     acc_now_delinq  acc_open_past_24mths addr_state  all_util  annual_inc  \
# 1                0                     4         MI      61.0     55000.0
# 4                0                     1         MT      43.0     67000.0
# 7                0                     2         VA      70.0    114000.0
# 25               0                     4         AZ      42.0     56000.0
# 30               0                     1         FL      51.0     65000.0
#
#     annual_inc_joint application_type  avg_cur_bal  bc_open_to_buy  bc_util  \
# 1                NaN       Individual      17223.0          7934.0     67.3
# 4                NaN       Individual      28493.0          5327.0     62.0
# 7                NaN       Individual      24630.0          1481.0     95.5
# 25               NaN       Individual      10710.0         17592.0     20.0
# 30               NaN       Individual      33958.0           722.0     27.8
#
# ...

# %% [markdown]
# ## Write out clean csv files

# %%
## Clean csv file to be saved in GitHub repository
secured_df.to_csv("DataSets/clean_loan_data_2017.csv", index=False,header=True)

# %%
## Clean csv file to be saved in GitHub repository
secured_df2.to_csv("DataSets/clean_loan_data_2018.csv", index=False,header=True)
