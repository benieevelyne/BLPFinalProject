# %% [markdown]
# ## Loan Data Prep

# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import date
from ipykernel import kernelapp as app

# %% [markdown]
# ## Read in Loan Data

# %%
# Read in 2017 csv files for review
df=pd.read_csv("static/data/LoanStats_2017Q1.csv", encoding="ISO-8859-1", engine='python',skiprows=1, skipfooter=2)
df2=pd.read_csv("static/data/LoanStats_2017Q2.csv", encoding="ISO-8859-1",engine = 'python',skiprows=1, skipfooter=2)
df3=pd.read_csv("static/data/LoanStats_2017Q3.csv", encoding="ISO-8859-1",engine='python',skiprows=1, skipfooter=2)
df4=pd.read_csv("static/data/LoanStats_2017Q4.csv", encoding="ISO-8859-1",engine='python',skiprows=1, skipfooter=2)

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
df['purpose'].unique()
# Out:
# array(['debt_consolidation', 'home_improvement', 'car', 'major_purchase',
#        'credit_card', 'vacation', 'medical', 'other', 'house', 'moving',
#        'small_business', 'renewable_energy'], dtype=object)

# %%
# Read in 2018 csv files for review
df5=pd.read_csv("static/data/LoanStats_2018Q1.csv", encoding="ISO-8859-1", engine='python', skiprows=1, skipfooter=2)
df6=pd.read_csv("static/data/LoanStats_2018Q2.csv", encoding="ISO-8859-1", engine ='python',skiprows=1, skipfooter=2)
df7=pd.read_csv("static/data/LoanStats_2018Q3.csv", encoding="ISO-8859-1", engine='python', skiprows=1, skipfooter=2)

# %%
df5.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
df5['purpose'].unique()
# Out:
# array(['credit_card', 'debt_consolidation', 'house', 'home_improvement',
#        'major_purchase', 'medical', 'other', 'moving', 'car',
#        'small_business', 'vacation', 'renewable_energy', 'wedding'],
#       dtype=object)

# %% [markdown]
# ## Merge datasets

# %%
# Merge all 2017 quarters
merge = [df,df2,df3,df4]
loan_df = pd.concat(merge, sort=False)
loan_df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      16000        16000          16000.0   60 months
# 1 NaN        NaN      11875        11875          11875.0   36 months
# 2 NaN        NaN      12000        12000          12000.0   36 months
# 3 NaN        NaN      25000        25000          25000.0   36 months
# 4 NaN        NaN       1500         1500           1500.0   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   12.74%       361.93     C        C1       ...
# 1   11.44%       391.26     B        B4       ...
# 2    7.99%       375.99     A        A5       ...
# 3   15.99%       878.81     C        C5       ...
# 4    5.32%        45.18     A        A1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 145 columns]

# %%
# Merge all 2018 quarters
merge2 = [df5,df6,df7]
loan2_df = pd.concat(merge2, sort=False)
loan2_df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       1000         1000           1000.0   36 months
# 1 NaN        NaN       3200         3200           3200.0   36 months
# 2 NaN        NaN      30000        30000          30000.0   36 months
# 3 NaN        NaN      10000        10000          10000.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   17.47%        35.89     D        D1       ...
# 1    7.96%       100.22     A        A5       ...
# 2    7.34%       930.99     A        A4       ...
# 3    7.96%       313.18     A        A5       ...
# 4   16.01%      1230.67     C        C5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 145 columns]

# %% [markdown]
# ## Retain Secured Loan Data Only

# %%
#keep just secured loan data
type_list = ('car','house','home_improvement')
secured_df = loan_df.loc[loan_df['purpose'].isin(type_list)]
secured_df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1  NaN        NaN      11875        11875          11875.0   36 months
# 4  NaN        NaN       1500         1500           1500.0   36 months
# 7  NaN        NaN      35000        35000          35000.0   60 months
# 25 NaN        NaN      12000        12000          12000.0   36 months
# 30 NaN        NaN      14000        14000          14000.0   36 months
#
#    int_rate  installment grade sub_grade       ...         \
# 1    11.44%       391.26     B        B4       ...
# 4     5.32%        45.18     A        A1       ...
# 7    25.49%      1037.38     E        E4       ...
# 25    6.99%       370.48     A        A2       ...
# 30    8.24%       440.27     B        B1       ...
#
#    hardship_payoff_balance_amount hardship_last_payment_amount  \
# 1                             NaN                          NaN
# 4                             NaN                          NaN
# 7                             NaN                          NaN
# 25                            NaN                          NaN
# 30                            NaN                          NaN
#
#    disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 1                 Cash                     N                       NaN
# 4                 Cash                     N                       NaN
# 7                 Cash                     N                       NaN
# 25                Cash                     N                       NaN
# 30                Cash                     N                       NaN
#
#    settlement_status settlement_date settlement_amount  settlement_percentage  \
# 1                NaN             NaN               NaN                    NaN
# 4                NaN             NaN               NaN                    NaN
# 7                NaN             NaN               NaN                    NaN
# 25               NaN             NaN               NaN                    NaN
# 30               NaN             NaN               NaN                    NaN
#
#     settlement_term
# 1               NaN
# 4               NaN
# 7               NaN
# 25              NaN
# 30              NaN
#
# [5 rows x 145 columns]

# %%
type_list2 = ('car','house','home_improvement')
secured_df2 = loan2_df.loc[loan2_df['purpose'].isin(type_list)]
secured_df2.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 2  NaN        NaN      30000        30000          30000.0   36 months
# 5  NaN        NaN       9000         9000           9000.0   36 months
# 16 NaN        NaN      35000        35000          35000.0   60 months
# 17 NaN        NaN      15000        15000          15000.0   36 months
# 38 NaN        NaN      20000        20000          20000.0   60 months
#
#    int_rate  installment grade sub_grade       ...         \
# 2     7.34%       930.99     A        A4       ...
# 5     5.31%       271.00     A        A1       ...
# 16   24.84%      1024.02     E        E3       ...
# 17    6.07%       456.81     A        A2       ...
# 38   26.77%       607.97     E        E5       ...
#
#    hardship_payoff_balance_amount hardship_last_payment_amount  \
# 2                             NaN                          NaN
# 5                             NaN                          NaN
# 16                            NaN                          NaN
# 17                            NaN                          NaN
# 38                            NaN                          NaN
#
#    disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 2                 Cash                     N                       NaN
# 5                 Cash                     N                       NaN
# 16                Cash                     N                       NaN
# 17                Cash                     N                       NaN
# 38                Cash                     N                       NaN
#
#    settlement_status settlement_date settlement_amount  settlement_percentage  \
# 2                NaN             NaN               NaN                    NaN
# 5                NaN             NaN               NaN                    NaN
# 16               NaN             NaN               NaN                    NaN
# 17               NaN             NaN               NaN                    NaN
# 38               NaN             NaN               NaN                    NaN
#
#     settlement_term
# 2               NaN
# 5               NaN
# 16              NaN
# 17              NaN
# 38              NaN
#
# [5 rows x 145 columns]

# %% [markdown]
# ## Write out clean csv files

# %%
## Clean csv file to be saved in GitHub repository
secured_df.to_csv("DataSets/clean_loan_data_2017.csv", index=False,header=True)

# %%
## Clean csv file to be saved in GitHub repository
secured_df2.to_csv("DataSets/clean_loan_data_2018.csv", index=False,header=True)
